# %% [markdown]
# ## Importing the Cleaned Data

# %% [markdown]
# #### Importing the Required Modules

# %%
import warnings

import pandas as pd

import numpy as np

import seaborn as sbn

import matplotlib.pylab as mat  #importing matplotlib for visualization of our data analysis

# %%
df = pd.read_csv("cleaned_sugarcane_data.csv")

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %% [markdown]
# _________________________________________________________________________________________________________________________

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# #### How many countries produce sugarcane from each continent ?

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %% [markdown]
# #### Creating a Bar chart for the above analysis

# %%
df["Continent"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# As we can see, Africa has the maximum number of countries which produces sugarcane.

# %% [markdown]
# #### Defining the Central Tendencies, min-max and quartiles of the Dataset

# %%
df.describe()
# Out:
#        Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# count      1.020000e+02                 102.000000      1.020000e+02
# mean       1.850372e+07              112952.435755      2.498981e+05
# std        8.419149e+07              176651.341929      1.137003e+06
# min        1.000000e+00                   0.000000      0.000000e+00
# 25%        6.251875e+04                3671.910000      1.104000e+03
# 50%        1.440044e+06               25572.500000      1.655800e+04
# 75%        6.426824e+06              146384.750000      8.047400e+04
# max        7.686784e+08              951087.000000      1.022620e+07
#
#        Yield(Kg/Hectare)
# count         102.000000
# mean        52628.078431
# std         30504.676683
# min            10.000000
# 25%         29072.025000
# 50%         54108.950000
# 75%         73282.700000
# max        129049.300000

# %% [markdown]
# ### Checking and defining the Outliers

# %%
mat.figure(figsize=(10,8))  # defining the size of the plots


mat.subplot(2,2,1)

sbn.boxplot(df["Production(Tons)"])  # Box-plot for the "Production" column

mat.title("Production(Tons)")


mat.subplot(2,2,2)

sbn.boxplot(df["Production_per_person(Kg)"])  # Box-plot for the "Production per person" column

mat.title("Production_per_person(Kg)")


mat.subplot(2,2,3)

sbn.boxplot(df["Acreage(Hectare)"])  # Box-plot for the "Acreage" column

mat.title("Acreage(Hectare)")


mat.subplot(2,2,4)

sbn.boxplot(df["Yield(Kg/Hectare)"])  # Box-plot for the "Yield" column

mat.title("Yield(Kg/Hectare)")


mat.show()

# %% [markdown]
# We have Outliers in the data but Outliers are required here as it shows the countries which has maximum production. And then we can see what are the reasons for outliers.

# %% [markdown]
# ### Distribution of the Columns

# %%
mat.figure(figsize = (10,10))



mat.subplot(2,2,1)

with warnings.catch_warnings():
    warnings.simplefilter(action='ignore', category=UserWarning)  # Ignoring unwanted Warnings to make the analysis clear
    warnings.simplefilter(action='ignore', category=FutureWarning)  # Ignoring unwanted Warnings to make the analysis clear
    sbn.distplot(df["Production(Tons)"])  # distplot for the "Productions" column
mat.title("Production(Tons)")



mat.subplot(2,2,2)

with warnings.catch_warnings():
    warnings.simplefilter(action='ignore', category=UserWarning)  # Ignoring unwanted Warnings to make the analysis clear
    warnings.simplefilter(action='ignore', category=FutureWarning)  # Ignoring unwanted Warnings to make the analysis clear
    sbn.distplot(df["Production_per_person(Kg)"])  # distplot for the "Productions per person" column
mat.title("Production_per_person(Kg)")



mat.subplot(2,2,3)

with warnings.catch_warnings():
    warnings.simplefilter(action='ignore', category=UserWarning)  # Ignoring unwanted Warnings to make the analysis clear
    warnings.simplefilter(action='ignore', category=FutureWarning)  # Ignoring unwanted Warnings to make the analysis clear
    sbn.distplot(df["Acreage(Hectare)"])  # distplot for the "Acreage" column
mat.title("Acreage(Hectare)")



mat.subplot(2,2,4)

with warnings.catch_warnings():
    warnings.simplefilter(action='ignore', category=UserWarning)  # Ignoring unwanted Warnings to make the analysis clear
    warnings.simplefilter(action='ignore', category=FutureWarning)  # Ignoring unwanted Warnings to make the analysis clear
    sbn.distplot(df["Yield(Kg/Hectare)"])  # distplot for the "Yield" column
mat.title("Yield(Kg/Hectare)")



mat.show()

# %% [markdown]
# #### Creating a Violin Plot for the "Productions of Sugarcane"

# %%
sbn.violinplot(df["Production(Tons)"])
# Out:
# <Axes: >

# %% [markdown]
# #### _________________________________________________________________________________________________________________________

# %% [markdown]
# # Bivariate Analysis

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %% [markdown]
# ### Which country produces maximum sugarcane ?

# %%
new_df = df[["Country","Production(Tons)"]].set_index("Country")

# %%
new_df
# Out:
#            Production(Tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0
# ...                     ...
# Spain                 394.0
# Lebanon                97.0
# Singapore              50.0
# Samoa                  12.0
# Syria                   1.0
#
# [102 rows x 1 columns]

# %% [markdown]
# ### Creating new column for the "Production Percentage" in the new Dataframe

# %%
new_df["Production(Tons)_percent"] = new_df["Production(Tons)"]*100/new_df["Production(Tons)"].sum()

# %%
new_df
# Out:
#            Production(Tons)  Production(Tons)_percent
# Country
# Brazil          768678382.0              4.072729e+01
# India           348448000.0              1.846200e+01
# China           123059739.0              6.520138e+00
# Thailand         87468496.0              4.634389e+00
# Pakistan         65450704.0              3.467809e+00
# ...                     ...                       ...
# Spain                 394.0              2.087551e-05
# Lebanon                97.0              5.139401e-06
# Singapore              50.0              2.649176e-06
# Samoa                  12.0              6.358022e-07
# Syria                   1.0              5.298352e-08
#
# [102 rows x 2 columns]

# %% [markdown]
# ### Creating a Pie Chart for the new Dataframe

# %%
new_df["Production(Tons)_percent"].plot(kind = "pie", autopct = "%.2f")
# Out:
# <Axes: ylabel='Production(Tons)_percent'>

# %% [markdown]
# Brazil, India and China contribute to almost 65% of production of sugarcane

# %% [markdown]
# ### Bar Chart for the above Analysis

# %%
df[["Country","Production(Tons)"]].set_index("Country").sort_values("Production(Tons)", ascending = False).head(15).plot(kind = "bar")
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# #### Creating a Bar plot with top 15 rows of the original dataframe

# %%
ax = sbn.barplot(data = df.head(15),  x= "Country", y = "Production(Tons)")

ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

mat.show()

# %% [markdown]
# The country "Brazil" produces maximum sugarcane out of all countries .   (Seleção Brazil)

# %% [markdown]
# ### Which country has highest land?

# %%
df_acr = df.sort_values("Acreage(Hectare)", ascending = False).head(15)  # Taking the top 15 values of the original dataset

px = sbn.barplot(data = df_acr,  x= "Country", y = "Acreage(Hectare)")

px.set_xticklabels(ax.get_xticklabels(),rotation =90)

mat.show()

# %% [markdown]
# "Brazil" has the largest amount of land dedicated for Sugarcane Production .   (Seleção Brazil)

# %% [markdown]
# ### Which country has highest yield per hectare?

# %%
df_yield = df.sort_values("Yield(Kg/Hectare)", ascending = False).head(15)  # Taking the top 15 values of the original dataset

dx = sbn.barplot(data = df_yield,  x= "Country", y = "Yield(Kg/Hectare)")

dx.set_xticklabels(ax.get_xticklabels(),rotation =90)

mat.show()

# %% [markdown]
# Guatemala has the highest yield(kg/hectare) for sugarcane . All hail the Latin America Countries.

# %% [markdown]
# ### Which country has highest production?

# %%
df_yield = df.sort_values("Production_per_person(Kg)", ascending = False).head(15)  # Taking the top 15 values of the original dataset

hx = sbn.barplot(data = df_yield,  x= "Country", y = "Production_per_person(Kg)")

hx.set_xticklabels(ax.get_xticklabels(),rotation =90)

mat.show()

# %% [markdown]
# Production per Person is highest in Paraguay . (Told ya, latin American countries are the best in the world)

# %% [markdown]
# # Correlation

# %%
df_corr = df.corr(numeric_only=True)
df_corr
# Out:
#                            Production(Tons)  Production_per_person(Kg)  \
# Production(Tons)                   1.000000                   0.015000
# Production_per_person(Kg)          0.015000                   1.000000
# Acreage(Hectare)                   0.997550                   0.012557
# Yield(Kg/Hectare)                  0.132812                   0.017999
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)
# Production(Tons)                   0.997550           0.132812
# Production_per_person(Kg)          0.012557           0.017999
# Acreage(Hectare)                   1.000000           0.113433
# Yield(Kg/Hectare)                  0.113433           1.000000

# %% [markdown]
# ### Heat-map for the above correlation

# %%
sbn.heatmap(df_corr, annot = True, cmap="Greens")
# Out:
# <Axes: >

# %% [markdown]
# # Do countries with highest land produce more sugarcane ?

# %%
# Creating a Scatter plot for the said analysis

sbn.scatterplot(data = df, x = "Acreage(Hectare)", y = "Production(Tons)", hue = "Continent" )
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# Conclusion - Overall increase in land increases the production

# %% [markdown]
# # Do countries which yield more sugarcane per hectare produces more sugarcane in total?

# %%
# Creating a Scatter plot for the said analysis

sbn.scatterplot(data = df, x = "Yield(Kg/Hectare)" , y = "Production(Tons)", hue = "Continent")
# Out:
# <Axes: xlabel='Yield(Kg/Hectare)', ylabel='Production(Tons)'>

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %% [markdown]
# # Analysis for different Continents

# %%
# Using the "Groupby" feature of Pandas Dataframe to rearrange the dataframe based on groups.

df_continent = df.groupby("Continent").sum()

df_country_concat = pd.DataFrame(df.groupby('Continent')['Country'].agg(', '.join))  # Separating the country names to make them clearly visible

df_continent["Country"] = df_country_concat["Country"]  # Adding the modified country names in the dataframe

df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         Egypt, South Africa, Kenya, Swaziland, Sudan, ...
# Asia           India, China, Thailand, Pakistan, Indonesia, P...
# Europe                                           Portugal, Spain
# North America  Mexico, Guatemala, United States of America, C...
# Oceania                 Australia, Fiji, Papua New Guinea, Samoa
# South America  Brazil, Colombia, Argentina, Peru, Ecuador, Bo...
#
#                Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# ...

# %%
df_continent["number_of_countries"] = df.groupby("Continent")["Country"].count()  #  Creating a new column to count number of countries in each row

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         Egypt, South Africa, Kenya, Swaziland, Sudan, ...
# Asia           India, China, Thailand, Pakistan, Indonesia, P...
# Europe                                           Portugal, Spain
# North America  Mexico, Guatemala, United States of America, C...
# Oceania                 Australia, Fiji, Papua New Guinea, Samoa
# South America  Brazil, Colombia, Argentina, Peru, Ecuador, Bo...
#
#                Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# ...

# %% [markdown]
# ### Which continent produces maximum sugarcane?

# %%
df_continent["Production(Tons)"].sort_values(ascending =  False).plot(kind = "bar")  # Bar graph to describe max sugarcane production continent-wise
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ### Do number of countries in a Continent effects production of sugarcane?

# %%
continent_names = df_continent.index.to_list()


sbn.lineplot(data = df_continent,x = "number_of_countries", y= "Production(Tons)" )  # Creating a Line Plot for the groupby'ed data


mat.xticks(df_continent["number_of_countries"], continent_names, rotation =90)


mat.show()

# %% [markdown]
# ### Do the Continent with highest land produces more sugarcane?

# %%
sbn.lineplot(data = df_continent,x = "Acreage(Hectare)", y= "Production(Tons)" )  # Creating a Line Plot for the above analysis
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# ### Production distribution by continent

# %%
df_continent["Production(Tons)"].plot(kind = "pie", autopct = "%.2f%%")  # Pie Chart to visualize the distribution of production of Sugarcane across all Conntinents


mat.title('Production Distribution by Continent')


mat.show()

# %% [markdown]
# # Correlation for the Continent

# %%
df_continent.corr(numeric_only=True)
# Out:
#                            Production(Tons)  Production_per_person(Kg)  \
# Production(Tons)                   1.000000                   0.522211
# Production_per_person(Kg)          0.522211                   1.000000
# Acreage(Hectare)                   0.994897                   0.463215
# Yield(Kg/Hectare)                  0.091201                   0.542961
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)
# Production(Tons)                   0.994897           0.091201
# Production_per_person(Kg)          0.463215           0.542961
# Acreage(Hectare)                   1.000000           0.111166
# Yield(Kg/Hectare)                  0.111166           1.000000

# %% [markdown]
# # _______________________________________________________________

# %% [markdown]
# # End of the Explanatory Sugarcane Production Data Analysis

# %% [markdown]
# #### Hope You liked it :)  Consider giving a star if you do :)
